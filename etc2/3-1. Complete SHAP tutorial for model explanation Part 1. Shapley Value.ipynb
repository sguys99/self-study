# %% [markdown]
# ## 3-1. Complete SHAP tutorial for model explanation Part 1. Shapley Value

# %% [markdown]
# <div style="text-align: right"> <b>Author : Kwang Myung Yu</b></div>

# %% [markdown]
# <div style="text-align: right"> Initial upload: 2022.05.31 </div>
# <div style="text-align: right"> Last update: 2022.05.31 </div>

# %% [markdown]
# - https://summer-hu-92978.medium.com/complete-shap-tutorial-for-model-explanation-part-1-shapley-value-b67c7f19908c

# %% [markdown]
# SHAP means SHapley Additive exPlanations

# %% [markdown]
# (1) Two key words SHapley and Additive
# (2) SHAP’s purpose is to explain something

# %% [markdown]
# ### SHapley

# %% [markdown]
# 예를 들어 세사람이 160만 달러의 수익을 얻었다면 어떻게 나누는게 공정할까

# %% [markdown]
# step1

# %% [markdown]
# 각각의 생산성, 두사람이 일했을 때 생산성을 안다고 가정하자.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# step2

# %% [markdown]
# marginal contribution을 어떻게 구하나.
#
# Allen&Bob는 95이다. Bob의 marginal contribution은 95-40=55 이다.
# Cindy&Bob는 120이다. Bob의 marginal contribution은 120-60=60 이다.
#
# Bob&Cindy는 120의 생산성을 보유하고 있다. ???

# %% [markdown]
# ![image.png](attachment:image.png)
